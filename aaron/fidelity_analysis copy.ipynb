# %%
import sys
sys.path.append('..')

import json
import pennylane as qml
import pennylane.numpy as np
from src.tests import calculate_heisenberg_fidelity_vs_noise
from src.plots import plot_fidelities_vs_noise, plot_fidelities_vs_noise_changing_depth

# %% [markdown]
# Parameters Definition

# %%
def block(weights, wires):
    qml.RY(weights[0], wires=wires[0])
    qml.RY(weights[1], wires=wires[1])
    qml.CNOT(wires=wires)

# %%
dev = qml.device("lightning.qubit", wires=4)

@qml.qnode(dev)
def circuit(template_weights):
    qml.MPS(
        wires=range(4),
        n_block_wires=2,
        block=block,
        n_params_block=2,
        template_weights=template_weights,
    )
    return qml.expval(qml.PauliZ(wires=2))

# %%
def costfunc(params):
    cost = 0
    for i in range(len(params)):
        if i < len(params) / 2:
            cost += circuit(params)
        else:
            cost -= circuit(params)
    return cost

# %%
params = np.random.random(size=[3, 2], requires_grad=True)
optimizer = qml.GradientDescentOptimizer(stepsize=0.1)

for k in range(100):
    if k % 20 == 0:
        print(f"Step {k}, cost: {costfunc(params)}")
    params = optimizer.step(costfunc, params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       4 for k in range(100):
#       5     if k % 20 == 0:
# ----> 6         print(f"Step {k}, cost: {costfunc(params)}")
#       7     params = optimizer.step(costfunc, params)
#
# Cell In[4], line 5, in costfunc(params)
#       3 for i in range(len(params)):
#       4     if i < len(params) / 2:
# ----> 5         cost += circuit(params)
#       6     else:
#       7         cost -= circuit(params)
#
# File c:\Users\aaron\AppData\Local\Programs\Python\Python311\Lib\site-packages\pennylane\qnode.py:800, in QNode.__call__(self, *args, **kwargs)
#     797         set_shots(self._original_device, override_shots)(self._update_gradient_fn)()
#     799 # construct the tape
# --> 800 self.construct(args, kwargs)
#     802 cache = self.execute_kwargs.get("cache", False)
#     803 using_custom_cache = (
#     804     hasattr(cache, "__getitem__")
#     805     and hasattr(cache, "__setitem__")
#     806     and hasattr(cache, "__delitem__")
#     807 )
#
# File c:\Users\aaron\AppData\Local\Programs\Python\Python311\Lib\site-packages\pennylane\qnode.py:711, in QNode.construct(self, args, kwargs)
#     708 def construct(self, args, kwargs):
#     709     """Call the quantum function with a tape context, ensuring the operations get queued."""
# --> 711     self._tape = make_qscript(self.func)(*args, **kwargs)
#     712     self._tape._queue_category = "_ops"
#     713     self._qfunc_output = self.tape._qfunc_output
#
# File c:\Users\aaron\AppData\Local\Programs\Python\Python311\Lib\site-packages\pennylane\tape\qscript.py:1346, in make_qscript.<locals>.wrapper(*args, **kwargs)
#    1344 def wrapper(*args, **kwargs):
#    1345     with AnnotatedQueue() as q:
# -> 1346         result = fn(*args, **kwargs)
#    1348     qscript = QuantumScript.from_queue(q)
#    1349     qscript._qfunc_output = result
#
# Cell In[3], line 5, in circuit(template_weights)
#       3 @qml.qnode(dev)
#       4 def circuit(template_weights):
# ----> 5     qml.MPS(
#       6         wires=range(4),
#       7         n_block_wires=2,
#       8         n_params_block=2,
#       9         template_weights=template_weights,
#      10     )
#      11     return qml.expval(qml.PauliZ(wires=2))
#
# TypeError: MPS.__init__() missing 1 required positional argument: 'block'

# %%
def create_Hamiltonian(h):
    """
    Function in charge of generating the Hamiltonian of the statement.
    Args:
        h (float): magnetic field strength
    Returns:
        (qml.Hamiltonian): Hamiltonian of the statement associated to h
    """


    couplings = [-h]
    ops = [qml.PauliX(3)]

    for i in range(3):
        couplings = [-h] + couplings
        ops = [qml.PauliX(i)] + ops   
    
    for i in range(4):
        couplings = [-1] + couplings
        ops = [qml.PauliZ(i)@qml.PauliZ((i+1)%4)] + ops

    return qml.Hamiltonian(couplings,ops)



dev = qml.device("default.qubit", wires=4)

@qml.qnode(dev)
def model(params, H):
    """
    To implement VQE you need an ansatz for the candidate ground state!
    Define here the VQE ansatz in terms of some parameters (params) that
    create the candidate ground state. These parameters will
    be optimized later.
    Args:
        params (numpy.array): parameters to be used in the variational circuit
        H (qml.Hamiltonian): Hamiltonian used to calculate the expected value
    Returns:
        (float): Expected value with respect to the Hamiltonian H
    """


    for i in range(4):
        qml.RY(params[i], wires=i)
    
    for i in range(4):
        qml.CNOT([i,(i+1)%4])
    for i in range(4):
        qml.RZ(params[i+4], wires=i)
        
    
    for i in range(4):
        qml.RY(params[i+8], wires=i)
    
    for i in range(4):
        qml.CNOT([i,(i+1)%4])
    for i in range(4):
        qml.RZ(params[i+12], wires=i)

    return qml.expval(H)


def train(h):
    """
    In this function you must design a subroutine that returns the
    parameters that best approximate the ground state.
    Args:
        h (float): magnetic field strength
    Returns:
        (numpy.array): parameters that best approximate the ground state.
    """


    step_size = 0.02
    opt = qml.GradientDescentOptimizer(stepsize=0.2)
    #opt = qml.QNGOptimizer(stepsize=step_size, approx="block-diag")
    H =  create_Hamiltonian(h)
    theta = np.array([np.pi/2 for i in range(16)], requires_grad=True)
    # Put your code here #
    # store the values of the cost function
    energy = [model(theta, H)]

    # store the values of the circuit parameter
    params = [theta]

    max_iterations = 500
    conv_tol = 1e-06

    for n in range(max_iterations):
        theta, prev_energy = opt.step_and_cost(model, theta, H=H)
        energy.append(model(theta, H))
        params.append(theta)

        conv = np.abs(energy[-1] - prev_energy)

        # if n % 2 == 0:
        print(f"Step = {n},  Energy = {energy[-1]:.8f} Ha")

        if conv <= conv_tol:
            break
    return theta


# These functions are responsible for testing the solution.
def run(test_case_input: str) -> str:
    ins = json.loads(test_case_input)
    params = train(ins)
    return str(model(params, create_Hamiltonian(ins)))


def check(solution_output: str, expected_output: str) -> None:
    solution_output = json.loads(solution_output)
    expected_output = json.loads(expected_output)
    assert np.allclose(
        solution_output, expected_output, rtol=1e-1
    ), "The expected value is not correct."


test_cases = [['1.0', '-5.226251859505506'], ['2.3', '-9.66382463698038']]

for i, (input_, expected_output) in enumerate(test_cases):
    print(f"Running test case {i} with input '{input_}'...")

    try:
        output = run(input_)

    except Exception as exc:
        print(f"Runtime Error. {exc}")

    else:
        if message := check(output, expected_output):
            print(f"Wrong Answer. Have: '{output}'. Want: '{expected_output}'.")

        else:
            print("Correct!")
# Out:
# Running test case 0 with input '1.0'...
# Step = 0,  Energy = -1.34013799 Ha
# Step = 1,  Energy = -2.34886836 Ha
# Step = 2,  Energy = -3.02123336 Ha
# Step = 3,  Energy = -3.51740041 Ha
# Step = 4,  Energy = -3.89557127 Ha
# Step = 5,  Energy = -4.16269662 Ha
# Step = 6,  Energy = -4.34011268 Ha
# Step = 7,  Energy = -4.45804681 Ha
# Step = 8,  Energy = -4.53819625 Ha
# Step = 9,  Energy = -4.59391304 Ha
# Step = 10,  Energy = -4.63410890 Ha
# Step = 11,  Energy = -4.66496690 Ha
# Step = 12,  Energy = -4.69064341 Ha
# Step = 13,  Energy = -4.71379336 Ha
# Step = 14,  Energy = -4.73601793 Ha
# Step = 15,  Energy = -4.75820404 Ha
# Step = 16,  Energy = -4.78075894 Ha
# Step = 17,  Energy = -4.80376736 Ha
# Step = 18,  Energy = -4.82710042 Ha
# Step = 19,  Energy = -4.85049698 Ha
# Step = 20,  Energy = -4.87362887 Ha
# Step = 21,  Energy = -4.89615424 Ha
# Step = 22,  Energy = -4.91775890 Ha
# Step = 23,  Energy = -4.93818439 Ha
# Step = 24,  Energy = -4.95724260 Ha
# Step = 25,  Energy = -4.97481842 Ha
# Step = 26,  Energy = -4.99086363 Ha
# Step = 27,  Energy = -5.00538558 Ha
# Step = 28,  Energy = -5.01843402 Ha
# Step = 29,  Energy = -5.03008836 Ha
# Step = 30,  Energy = -5.04044677 Ha
# Step = 31,  Energy = -5.04961742 Ha
# Step = 32,  Energy = -5.05771191 Ha
# Step = 33,  Energy = -5.06484062 Ha
# Step = 34,  Energy = -5.07110941 Ha
# Step = 35,  Energy = -5.07661762 Ha
# Step = 36,  Energy = -5.08145684 Ha
# Step = 37,  Energy = -5.08571026 Ha
# Step = 38,  Energy = -5.08945259 Ha
# Step = 39,  Energy = -5.09275024 Ha
# Step = 40,  Energy = -5.09566175 Ha
# Step = 41,  Energy = -5.09823833 Ha
# Step = 42,  Energy = -5.10052450 Ha
# Step = 43,  Energy = -5.10255881 Ha
# Step = 44,  Energy = -5.10437446 Ha
# Step = 45,  Energy = -5.10600000 Ha
# Step = 46,  Energy = -5.10745988 Ha
# Step = 47,  Energy = -5.10877506 Ha
# Step = 48,  Energy = -5.10996347 Ha
# Step = 49,  Energy = -5.11104044 Ha
# Step = 50,  Energy = -5.11201914 Ha
# Step = 51,  Energy = -5.11291085 Ha
# Step = 52,  Energy = -5.11372527 Ha
# Step = 53,  Energy = -5.11447079 Ha
# Step = 54,  Energy = -5.11515463 Ha
# Step = 55,  Energy = -5.11578310 Ha
# Step = 56,  Energy = -5.11636168 Ha
# Step = 57,  Energy = -5.11689515 Ha
# Step = 58,  Energy = -5.11738774 Ha
# Step = 59,  Energy = -5.11784317 Ha
# Step = 60,  Energy = -5.11826473 Ha
# Step = 61,  Energy = -5.11865535 Ha
# Step = 62,  Energy = -5.11901765 Ha
# Step = 63,  Energy = -5.11935398 Ha
# Step = 64,  Energy = -5.11966646 Ha
# Step = 65,  Energy = -5.11995698 Ha
# Step = 66,  Energy = -5.12022728 Ha
# Step = 67,  Energy = -5.12047891 Ha
# Step = 68,  Energy = -5.12071332 Ha
# Step = 69,  Energy = -5.12093179 Ha
# Step = 70,  Energy = -5.12113553 Ha
# Step = 71,  Energy = -5.12132561 Ha
# Step = 72,  Energy = -5.12150303 Ha
# Step = 73,  Energy = -5.12166872 Ha
# Step = 74,  Energy = -5.12182352 Ha
# Step = 75,  Energy = -5.12196820 Ha
# Step = 76,  Energy = -5.12210349 Ha
# Step = 77,  Energy = -5.12223004 Ha
# Step = 78,  Energy = -5.12234846 Ha
# Step = 79,  Energy = -5.12245932 Ha
# Step = 80,  Energy = -5.12256315 Ha
# Step = 81,  Energy = -5.12266041 Ha
# Step = 82,  Energy = -5.12275156 Ha
# Step = 83,  Energy = -5.12283702 Ha
# Step = 84,  Energy = -5.12291716 Ha
# Step = 85,  Energy = -5.12299235 Ha
# Step = 86,  Energy = -5.12306291 Ha
# Step = 87,  Energy = -5.12312915 Ha
# Step = 88,  Energy = -5.12319136 Ha
# Step = 89,  Energy = -5.12324979 Ha
# Step = 90,  Energy = -5.12330470 Ha
# Step = 91,  Energy = -5.12335631 Ha
# Step = 92,  Energy = -5.12340484 Ha
# Step = 93,  Energy = -5.12345048 Ha
# Step = 94,  Energy = -5.12349342 Ha
# Step = 95,  Energy = -5.12353382 Ha
# Step = 96,  Energy = -5.12357186 Ha
# Step = 97,  Energy = -5.12360767 Ha
# Step = 98,  Energy = -5.12364139 Ha
# Step = 99,  Energy = -5.12367317 Ha
# Step = 100,  Energy = -5.12370310 Ha
# Step = 101,  Energy = -5.12373132 Ha
# Step = 102,  Energy = -5.12375792 Ha
# Step = 103,  Energy = -5.12378300 Ha
# Step = 104,  Energy = -5.12380666 Ha
# Step = 105,  Energy = -5.12382898 Ha
# Step = 106,  Energy = -5.12385004 Ha
# Step = 107,  Energy = -5.12386991 Ha
# Step = 108,  Energy = -5.12388867 Ha
# Step = 109,  Energy = -5.12390638 Ha
# Step = 110,  Energy = -5.12392311 Ha
# Step = 111,  Energy = -5.12393891 Ha
# Step = 112,  Energy = -5.12395383 Ha
# Step = 113,  Energy = -5.12396793 Ha
# Step = 114,  Energy = -5.12398125 Ha
# Step = 115,  Energy = -5.12399385 Ha
# Step = 116,  Energy = -5.12400575 Ha
# Step = 117,  Energy = -5.12401701 Ha
# Step = 118,  Energy = -5.12402765 Ha
# Step = 119,  Energy = -5.12403772 Ha
# Step = 120,  Energy = -5.12404724 Ha
# Step = 121,  Energy = -5.12405625 Ha
# Step = 122,  Energy = -5.12406477 Ha
# Step = 123,  Energy = -5.12407284 Ha
# Step = 124,  Energy = -5.12408047 Ha
# Step = 125,  Energy = -5.12408769 Ha
# Step = 126,  Energy = -5.12409453 Ha
# Step = 127,  Energy = -5.12410101 Ha
# Step = 128,  Energy = -5.12410714 Ha
# Step = 129,  Energy = -5.12411294 Ha
# Step = 130,  Energy = -5.12411844 Ha
# Step = 131,  Energy = -5.12412365 Ha
# Step = 132,  Energy = -5.12412858 Ha
# Step = 133,  Energy = -5.12413325 Ha
# Step = 134,  Energy = -5.12413768 Ha
# Step = 135,  Energy = -5.12414188 Ha
# Step = 136,  Energy = -5.12414585 Ha
# Step = 137,  Energy = -5.12414962 Ha
# Step = 138,  Energy = -5.12415319 Ha
# Step = 139,  Energy = -5.12415657 Ha
# Step = 140,  Energy = -5.12415978 Ha
# Step = 141,  Energy = -5.12416282 Ha
# Step = 142,  Energy = -5.12416571 Ha
# Step = 143,  Energy = -5.12416844 Ha
# Step = 144,  Energy = -5.12417104 Ha
# Step = 145,  Energy = -5.12417350 Ha
# Step = 146,  Energy = -5.12417583 Ha
# Step = 147,  Energy = -5.12417804 Ha
# Step = 148,  Energy = -5.12418014 Ha
# Step = 149,  Energy = -5.12418213 Ha
# Step = 150,  Energy = -5.12418402 Ha
# Step = 151,  Energy = -5.12418581 Ha
# Step = 152,  Energy = -5.12418751 Ha
# Step = 153,  Energy = -5.12418912 Ha
# Step = 154,  Energy = -5.12419065 Ha
# Step = 155,  Energy = -5.12419210 Ha
# Step = 156,  Energy = -5.12419348 Ha
# Step = 157,  Energy = -5.12419478 Ha
# Step = 158,  Energy = -5.12419602 Ha
# Step = 159,  Energy = -5.12419720 Ha
# Step = 160,  Energy = -5.12419832 Ha
# Step = 161,  Energy = -5.12419938 Ha
# Step = 162,  Energy = -5.12420039 Ha
# Step = 163,  Energy = -5.12420134 Ha
# Correct!
# Running test case 1 with input '2.3'...
# Step = 0,  Energy = -2.99763129 Ha
# Step = 1,  Energy = -4.15593462 Ha
# Step = 2,  Energy = -4.84788043 Ha
# Step = 3,  Energy = -5.41777010 Ha
# Step = 4,  Energy = -5.92474329 Ha
# Step = 5,  Energy = -6.44344668 Ha
# Step = 6,  Energy = -7.04396005 Ha
# Step = 7,  Energy = -7.79990023 Ha
# Step = 8,  Energy = -8.57081235 Ha
# Step = 9,  Energy = -9.04141940 Ha
# Step = 10,  Energy = -9.25253342 Ha
# Step = 11,  Energy = -9.35601450 Ha
# Step = 12,  Energy = -9.41116231 Ha
# Step = 13,  Energy = -9.44167190 Ha
# Step = 14,  Energy = -9.45895938 Ha
# Step = 15,  Energy = -9.46891830 Ha
# Step = 16,  Energy = -9.47469750 Ha
# Step = 17,  Energy = -9.47789280 Ha
# Step = 18,  Energy = -9.47914355 Ha
# Step = 19,  Energy = -9.47825896 Ha
# Step = 20,  Energy = -9.47404593 Ha
# Step = 21,  Energy = -9.46356652 Ha
# Step = 22,  Energy = -9.44050679 Ha
# Step = 23,  Energy = -9.39195698 Ha
# Step = 24,  Energy = -9.29232812 Ha
# Step = 25,  Energy = -9.09675777 Ha
# Step = 26,  Energy = -8.74085709 Ha
# Step = 27,  Energy = -8.19754714 Ha
# Step = 28,  Energy = -7.59780060 Ha
# Step = 29,  Energy = -7.31725113 Ha
# Step = 30,  Energy = -7.51571152 Ha
# Step = 31,  Energy = -8.02973394 Ha
# Step = 32,  Energy = -8.49023547 Ha
# Step = 33,  Energy = -8.87392973 Ha
# Step = 34,  Energy = -9.10461811 Ha
# Step = 35,  Energy = -9.26033800 Ha
# Step = 36,  Energy = -9.35005971 Ha
# Step = 37,  Energy = -9.40716752 Ha
# Step = 38,  Energy = -9.44087403 Ha
# Step = 39,  Energy = -9.46209864 Ha
# Step = 40,  Energy = -9.47500016 Ha
# Step = 41,  Energy = -9.48317917 Ha
# Step = 42,  Energy = -9.48830407 Ha
# Step = 43,  Energy = -9.49162394 Ha
# Step = 44,  Energy = -9.49379375 Ha
# Step = 45,  Energy = -9.49526488 Ha
# Step = 46,  Energy = -9.49629202 Ha
# Step = 47,  Energy = -9.49704168 Ha
# Step = 48,  Energy = -9.49761181 Ha
# Step = 49,  Energy = -9.49806435 Ha
# Step = 50,  Energy = -9.49843677 Ha
# Step = 51,  Energy = -9.49875251 Ha
# Step = 52,  Energy = -9.49902623 Ha
# Step = 53,  Energy = -9.49926730 Ha
# Step = 54,  Energy = -9.49948199 Ha
# Step = 55,  Energy = -9.49967457 Ha
# Step = 56,  Energy = -9.49984819 Ha
# Step = 57,  Energy = -9.50000524 Ha
# Step = 58,  Energy = -9.50014766 Ha
# Step = 59,  Energy = -9.50027707 Ha
# Step = 60,  Energy = -9.50039484 Ha
# Step = 61,  Energy = -9.50050222 Ha
# Step = 62,  Energy = -9.50060028 Ha
# Step = 63,  Energy = -9.50068999 Ha
# Step = 64,  Energy = -9.50077223 Ha
# Step = 65,  Energy = -9.50084777 Ha
# Step = 66,  Energy = -9.50091733 Ha
# Step = 67,  Energy = -9.50098154 Ha
# Step = 68,  Energy = -9.50104097 Ha
# Step = 69,  Energy = -9.50109613 Ha
# Step = 70,  Energy = -9.50114747 Ha
# Step = 71,  Energy = -9.50119541 Ha
# Step = 72,  Energy = -9.50124032 Ha
# Step = 73,  Energy = -9.50128252 Ha
# Step = 74,  Energy = -9.50132232 Ha
# Step = 75,  Energy = -9.50135996 Ha
# Step = 76,  Energy = -9.50139569 Ha
# Step = 77,  Energy = -9.50142971 Ha
# Step = 78,  Energy = -9.50146221 Ha
# Step = 79,  Energy = -9.50149336 Ha
# Step = 80,  Energy = -9.50152331 Ha
# Step = 81,  Energy = -9.50155219 Ha
# Step = 82,  Energy = -9.50158012 Ha
# Step = 83,  Energy = -9.50160721 Ha
# Step = 84,  Energy = -9.50163356 Ha
# Step = 85,  Energy = -9.50165925 Ha
# Step = 86,  Energy = -9.50168435 Ha
# Step = 87,  Energy = -9.50170895 Ha
# Step = 88,  Energy = -9.50173310 Ha
# Step = 89,  Energy = -9.50175686 Ha
# Step = 90,  Energy = -9.50178029 Ha
# Step = 91,  Energy = -9.50180344 Ha
# Step = 92,  Energy = -9.50182634 Ha
# Step = 93,  Energy = -9.50184905 Ha
# Step = 94,  Energy = -9.50187159 Ha
# Step = 95,  Energy = -9.50189401 Ha
# Step = 96,  Energy = -9.50191634 Ha
# Step = 97,  Energy = -9.50193861 Ha
# Step = 98,  Energy = -9.50196085 Ha
# Step = 99,  Energy = -9.50198310 Ha
# Step = 100,  Energy = -9.50200537 Ha
# Step = 101,  Energy = -9.50202769 Ha
# Step = 102,  Energy = -9.50205010 Ha
# Step = 103,  Energy = -9.50207261 Ha
# Step = 104,  Energy = -9.50209526 Ha
# Step = 105,  Energy = -9.50211806 Ha
# Step = 106,  Energy = -9.50214104 Ha
# Step = 107,  Energy = -9.50216423 Ha
# Step = 108,  Energy = -9.50218765 Ha
# Step = 109,  Energy = -9.50221132 Ha
# Step = 110,  Energy = -9.50223528 Ha
# Step = 111,  Energy = -9.50225954 Ha
# Step = 112,  Energy = -9.50228414 Ha
# Step = 113,  Energy = -9.50230910 Ha
# Step = 114,  Energy = -9.50233445 Ha
# Step = 115,  Energy = -9.50236022 Ha
# Step = 116,  Energy = -9.50238644 Ha
# Step = 117,  Energy = -9.50241313 Ha
# Step = 118,  Energy = -9.50244034 Ha
# Step = 119,  Energy = -9.50246810 Ha
# Step = 120,  Energy = -9.50249644 Ha
# Step = 121,  Energy = -9.50252539 Ha
# Step = 122,  Energy = -9.50255501 Ha
# Step = 123,  Energy = -9.50258532 Ha
# Step = 124,  Energy = -9.50261637 Ha
# Step = 125,  Energy = -9.50264821 Ha
# Step = 126,  Energy = -9.50268089 Ha
# Step = 127,  Energy = -9.50271445 Ha
# Step = 128,  Energy = -9.50274896 Ha
# Step = 129,  Energy = -9.50278445 Ha
# Step = 130,  Energy = -9.50282101 Ha
# Step = 131,  Energy = -9.50285869 Ha
# Step = 132,  Energy = -9.50289755 Ha
# Step = 133,  Energy = -9.50293768 Ha
# Step = 134,  Energy = -9.50297915 Ha
# Step = 135,  Energy = -9.50302203 Ha
# Step = 136,  Energy = -9.50306643 Ha
# Step = 137,  Energy = -9.50311243 Ha
# Step = 138,  Energy = -9.50316014 Ha
# Step = 139,  Energy = -9.50320965 Ha
# Step = 140,  Energy = -9.50326109 Ha
# Step = 141,  Energy = -9.50331459 Ha
# Step = 142,  Energy = -9.50337026 Ha
# Step = 143,  Energy = -9.50342826 Ha
# Step = 144,  Energy = -9.50348874 Ha
# Step = 145,  Energy = -9.50355187 Ha
# Step = 146,  Energy = -9.50361781 Ha
# Step = 147,  Energy = -9.50368676 Ha
# Step = 148,  Energy = -9.50375893 Ha
# Step = 149,  Energy = -9.50383454 Ha
# Step = 150,  Energy = -9.50391382 Ha
# Step = 151,  Energy = -9.50399704 Ha
# Step = 152,  Energy = -9.50408448 Ha
# Step = 153,  Energy = -9.50417644 Ha
# Step = 154,  Energy = -9.50427324 Ha
# Step = 155,  Energy = -9.50437525 Ha
# Step = 156,  Energy = -9.50448285 Ha
# Step = 157,  Energy = -9.50459645 Ha
# Step = 158,  Energy = -9.50471651 Ha
# Step = 159,  Energy = -9.50484353 Ha
# Step = 160,  Energy = -9.50497803 Ha
# Step = 161,  Energy = -9.50512061 Ha
# Step = 162,  Energy = -9.50527189 Ha
# Step = 163,  Energy = -9.50543256 Ha
# Step = 164,  Energy = -9.50560338 Ha
# Step = 165,  Energy = -9.50578516 Ha
# Step = 166,  Energy = -9.50597880 Ha
# Step = 167,  Energy = -9.50618526 Ha
# Step = 168,  Energy = -9.50640561 Ha
# Step = 169,  Energy = -9.50664100 Ha
# Step = 170,  Energy = -9.50689268 Ha
# Step = 171,  Energy = -9.50716203 Ha
# Step = 172,  Energy = -9.50745055 Ha
# Step = 173,  Energy = -9.50775985 Ha
# Step = 174,  Energy = -9.50809171 Ha
# Step = 175,  Energy = -9.50844807 Ha
# Step = 176,  Energy = -9.50883100 Ha
# Step = 177,  Energy = -9.50924279 Ha
# Step = 178,  Energy = -9.50968590 Ha
# Step = 179,  Energy = -9.51016301 Ha
# Step = 180,  Energy = -9.51067701 Ha
# Step = 181,  Energy = -9.51123100 Ha
# Step = 182,  Energy = -9.51182833 Ha
# Step = 183,  Energy = -9.51247261 Ha
# Step = 184,  Energy = -9.51316768 Ha
# Step = 185,  Energy = -9.51391763 Ha
# Step = 186,  Energy = -9.51472680 Ha
# Step = 187,  Energy = -9.51559977 Ha
# Step = 188,  Energy = -9.51654135 Ha
# Step = 189,  Energy = -9.51755653 Ha
# Step = 190,  Energy = -9.51865049 Ha
# Step = 191,  Energy = -9.51982851 Ha
# Step = 192,  Energy = -9.52109594 Ha
# Step = 193,  Energy = -9.52245813 Ha
# Step = 194,  Energy = -9.52392033 Ha
# Step = 195,  Energy = -9.52548760 Ha
# Step = 196,  Energy = -9.52716469 Ha
# Step = 197,  Energy = -9.52895592 Ha
# Step = 198,  Energy = -9.53086503 Ha
# Step = 199,  Energy = -9.53289500 Ha
# Step = 200,  Energy = -9.53504796 Ha
# Step = 201,  Energy = -9.53732496 Ha
# Step = 202,  Energy = -9.53972586 Ha
# Step = 203,  Energy = -9.54224913 Ha
# Step = 204,  Energy = -9.54489181 Ha
# Step = 205,  Energy = -9.54764932 Ha
# Step = 206,  Energy = -9.55051542 Ha
# Step = 207,  Energy = -9.55348219 Ha
# Step = 208,  Energy = -9.55654004 Ha
# Step = 209,  Energy = -9.55967774 Ha
# Step = 210,  Energy = -9.56288255 Ha
# Step = 211,  Energy = -9.56614038 Ha
# Step = 212,  Energy = -9.56943598 Ha
# Step = 213,  Energy = -9.57275320 Ha
# Step = 214,  Energy = -9.57607529 Ha
# Step = 215,  Energy = -9.57938518 Ha
# Step = 216,  Energy = -9.58266582 Ha
# Step = 217,  Energy = -9.58590056 Ha
# Step = 218,  Energy = -9.58907342 Ha
# Step = 219,  Energy = -9.59216941 Ha
# Step = 220,  Energy = -9.59517485 Ha
# Step = 221,  Energy = -9.59807754 Ha
# Step = 222,  Energy = -9.60086700 Ha
# Step = 223,  Energy = -9.60353454 Ha
# Step = 224,  Energy = -9.60607336 Ha
# Step = 225,  Energy = -9.60847854 Ha
# Step = 226,  Energy = -9.61074703 Ha
# Step = 227,  Energy = -9.61287747 Ha
# Step = 228,  Energy = -9.61487016 Ha
# Step = 229,  Energy = -9.61672682 Ha
# Step = 230,  Energy = -9.61845043 Ha
# Step = 231,  Energy = -9.62004503 Ha
# Step = 232,  Energy = -9.62151554 Ha
# Step = 233,  Energy = -9.62286753 Ha
# Step = 234,  Energy = -9.62410710 Ha
# Step = 235,  Energy = -9.62524065 Ha
# Step = 236,  Energy = -9.62627477 Ha
# Step = 237,  Energy = -9.62721611 Ha
# Step = 238,  Energy = -9.62807125 Ha
# Step = 239,  Energy = -9.62884666 Ha
# Step = 240,  Energy = -9.62954859 Ha
# Step = 241,  Energy = -9.63018301 Ha
# Step = 242,  Energy = -9.63075563 Ha
# Step = 243,  Energy = -9.63127180 Ha
# Step = 244,  Energy = -9.63173655 Ha
# Step = 245,  Energy = -9.63215457 Ha
# Step = 246,  Energy = -9.63253021 Ha
# Step = 247,  Energy = -9.63286748 Ha
# Step = 248,  Energy = -9.63317006 Ha
# Step = 249,  Energy = -9.63344135 Ha
# Step = 250,  Energy = -9.63368441 Ha
# Step = 251,  Energy = -9.63390208 Ha
# Step = 252,  Energy = -9.63409690 Ha
# Step = 253,  Energy = -9.63427120 Ha
# Step = 254,  Energy = -9.63442707 Ha
# Step = 255,  Energy = -9.63456642 Ha
# Step = 256,  Energy = -9.63469095 Ha
# Step = 257,  Energy = -9.63480222 Ha
# Step = 258,  Energy = -9.63490160 Ha
# Step = 259,  Energy = -9.63499035 Ha
# Step = 260,  Energy = -9.63506958 Ha
# Step = 261,  Energy = -9.63514031 Ha
# Step = 262,  Energy = -9.63520344 Ha
# Step = 263,  Energy = -9.63525977 Ha
# Step = 264,  Energy = -9.63531003 Ha
# Step = 265,  Energy = -9.63535487 Ha
# Step = 266,  Energy = -9.63539488 Ha
# Step = 267,  Energy = -9.63543056 Ha
# Step = 268,  Energy = -9.63546238 Ha
# Step = 269,  Energy = -9.63549077 Ha
# Step = 270,  Energy = -9.63551608 Ha
# Step = 271,  Energy = -9.63553865 Ha
# Step = 272,  Energy = -9.63555878 Ha
# Step = 273,  Energy = -9.63557672 Ha
# Step = 274,  Energy = -9.63559272 Ha
# Step = 275,  Energy = -9.63560699 Ha
# Step = 276,  Energy = -9.63561970 Ha
# Step = 277,  Energy = -9.63563104 Ha
# Step = 278,  Energy = -9.63564115 Ha
# Step = 279,  Energy = -9.63565016 Ha
# Step = 280,  Energy = -9.63565819 Ha
# Step = 281,  Energy = -9.63566536 Ha
# Step = 282,  Energy = -9.63567174 Ha
# Step = 283,  Energy = -9.63567743 Ha
# Step = 284,  Energy = -9.63568250 Ha
# Step = 285,  Energy = -9.63568702 Ha
# Step = 286,  Energy = -9.63569105 Ha
# Step = 287,  Energy = -9.63569465 Ha
# Step = 288,  Energy = -9.63569785 Ha
# Step = 289,  Energy = -9.63570070 Ha
# Step = 290,  Energy = -9.63570325 Ha
# Step = 291,  Energy = -9.63570551 Ha
# Step = 292,  Energy = -9.63570753 Ha
# Step = 293,  Energy = -9.63570934 Ha
# Step = 294,  Energy = -9.63571094 Ha
# Step = 295,  Energy = -9.63571237 Ha
# Step = 296,  Energy = -9.63571365 Ha
# Step = 297,  Energy = -9.63571479 Ha
# Step = 298,  Energy = -9.63571580 Ha
# Step = 299,  Energy = -9.63571670 Ha
# Correct!
