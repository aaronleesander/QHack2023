# %%
import sys
sys.path.append('..\..')
# print(sys.path)
import matplotlib.pyplot as plt
import pickle
import os
from src.tests import calculate_heisenberg_runtime_vs_qubits
from src.plots import plot_runtimes_vs_qubits

# %% [markdown]
# Parameters Definition

# %%
file_name="runtimes_CPU.pickle"
open_file = open(file_name, "rb")
CPU_times = pickle.load(open_file)
open_file.close()

file_name="runtimes_GPU.pickle"
open_file = open(file_name, "rb")
GPU_times = pickle.load(open_file)
open_file.close()

# %%
plot_runtimes_vs_qubits(range(2,26), CPU_times, GPU_times)
