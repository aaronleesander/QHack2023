# %%
import matplotlib.pyplot as plt
import pickle

import sys
sys.path.append('../..')
from src.plots import plot_runtimes_vs_qubits

# %%
filename = './gpu_cpu/runtimes_CPU.pickle'
with open(filename, mode='rb') as f:
    cpu_times = pickle.load(f)

filename = './gpu_cpu/runtimes_GPU.pickle'
with open(filename, mode='rb') as f:
    Gpu_times = pickle.load(f)

# %%
plot_runtimes_vs_qubits(cpu_times, Gpu_times, depth=100)
