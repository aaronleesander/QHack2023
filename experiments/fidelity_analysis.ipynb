# %%
import sys
sys.path.append('..')

import numpy as np
from src.tests import calculate_heisenberg_fidelity_vs_noise
from src.plots import plot_fidelities_vs_noise, plot_fidelities_vs_noise_changing_depth

# %% [markdown]
# Parameters Definition

# %%
wires = 6
couplings = {"J_xx": 1, "J_yy": 2, "J_zz": 1, "h": 0.5}
T = 1
depth = 100

p_list = np.logspace(-9, 0, 30)
samples = 10

# %% [markdown]
# Runtime Calculations

# %%
fidelities = calculate_heisenberg_fidelity_vs_noise("lightning.qubit", wires, couplings, T, depth, p_list, samples)

# %% [markdown]
# Plots

# %%
plot_fidelities_vs_noise(p_list, fidelities, depth)

# %%
wires = 10
couplings = {"J_xx": 1, "J_yy": 1, "J_zz": 1, "h": 0.5}
T = 1
depth_list = [1, 10, 20, 50, 100]

p_list = np.logspace(-9, 0, 10)
samples = 10

# %%
fidelities_list = []
for depth in depth_list:
    fidelities = calculate_heisenberg_fidelity_vs_noise("lightning.qubit", wires, couplings, T, depth, p_list)
    fidelities_list.append(fidelities)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 fidelities_list = []
#       2 for depth in depth_list:
# ----> 3     fidelities = calculate_heisenberg_fidelity_vs_noise("lightning.qubit", wires, couplings, T, depth, p_list)
#       4     fidelities_list.append(fidelities)
#
# TypeError: calculate_heisenberg_fidelity_vs_noise() missing 1 required positional argument: 'samples'

# %%
plot_fidelities_vs_noise_changing_depth(p_list, fidelities_list, depth_list)
